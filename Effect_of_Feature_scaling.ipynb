# %% [markdown]
# <a href="https://colab.research.google.com/github/Siddhant254/Deep-Learning-Concepts/blob/master/Effect_of_Feature_scaling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/content/Social_Network_Ads.csv')

# %%
df = df.iloc[:,2:]
df.head()
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0

# %%
import seaborn as sns

# %%
sns.scatterplot(x = df.iloc[:,0], y = df.iloc[:,1])
# Out:
# <Axes: xlabel='Age', ylabel='EstimatedSalary'>

# %%
X = df.iloc[:,0:2]
y = df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
import tensorflow as tf
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense

# %%
model = Sequential()

model.add(Dense(128,activation='relu',input_dim=2))
model.add(Dense(1,activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 128)               384
#
#  dense_1 (Dense)             (None, 1)                 129
#
# ...
# Total params: 513
# Trainable params: 513
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
history = model.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=100)
# Out:
# Epoch 1/100
# 10/10 [==============================] - 1s 28ms/step - loss: 4727.4380 - accuracy: 0.6531 - val_loss: 2619.9985 - val_accuracy: 0.6000
# Epoch 2/100
# 10/10 [==============================] - 0s 7ms/step - loss: 1141.0508 - accuracy: 0.4969 - val_loss: 1004.6434 - val_accuracy: 0.4000
# Epoch 3/100
# 10/10 [==============================] - 0s 6ms/step - loss: 578.8404 - accuracy: 0.4594 - val_loss: 457.4909 - val_accuracy: 0.6000
# Epoch 4/100
# 10/10 [==============================] - 0s 7ms/step - loss: 271.3056 - accuracy: 0.4594 - val_loss: 76.8051 - val_accuracy: 0.4000
# Epoch 5/100
# 10/10 [==============================] - 0s 7ms/step - loss: 181.3330 - accuracy: 0.5781 - val_loss: 232.8433 - val_accuracy: 0.4000
# Epoch 6/100
# 10/10 [==============================] - 0s 7ms/step - loss: 170.4149 - accuracy: 0.5719 - val_loss: 179.3387 - val_accuracy: 0.6000
# Epoch 7/100
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['val_accuracy'])

# %%
# Applying scaling

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
X_train_scaled
# Out:
# array([[ 0.88928823, -0.65924556],
#        [-0.17254846,  0.87392651],
#        [-1.04132394, -0.36440478],
#        [ 0.98581884,  0.6085698 ],
#        [-0.94479333,  0.57908572],
#        [ 0.40663519,  0.01888824],
#        [ 0.98581884,  2.11225779],
#        [ 0.31010458, -0.30543662],
#        [ 1.7580637 , -0.27595254],
#        [-0.17254846,  2.20071003],
#        [ 1.7580637 ,  1.0213469 ],
#        [-1.33091576, -1.48479975],
#        [ 2.04765553,  0.54960165],
#        [ 1.27541066,  1.90586924],
#        [-1.13785454,  0.31372902],
#        [-0.36560968, -0.77718187],
#        [-1.71703819,  0.49063349],
#        [-0.5586709 , -1.51428383],
#        [ 0.31010458, -0.71821372],
#        [ 0.02051275, -0.57079333],
#        [ 0.02051275,  0.04837232],
#        [-0.07601785, -0.51182517],
#        [-0.6552015 , -1.51428383],
#        [ 0.02051275,  0.31372902],
#        [ 0.31010458,  0.07785639],
#        [-0.46214029, -1.13099081],
#        [-0.75173211, -1.54376791],
# ...

# %%
sns.scatterplot(x = X_train_scaled[:,0], y = X_train_scaled[:,1])
# Out:
# <Axes: >

# %%
model = Sequential()

model.add(Dense(128,activation='relu',input_dim=2))
model.add(Dense(1,activation='sigmoid'))

model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

history = model.fit(X_train_scaled,y_train,validation_data=(X_test_scaled,y_test),epochs=100)
# Out:
# Epoch 1/100
# 10/10 [==============================] - 2s 52ms/step - loss: 0.7262 - accuracy: 0.3562 - val_loss: 0.6860 - val_accuracy: 0.6125
# Epoch 2/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.6637 - accuracy: 0.7094 - val_loss: 0.6269 - val_accuracy: 0.7875
# Epoch 3/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.6132 - accuracy: 0.7937 - val_loss: 0.5770 - val_accuracy: 0.8250
# Epoch 4/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.5705 - accuracy: 0.8406 - val_loss: 0.5340 - val_accuracy: 0.8375
# Epoch 5/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.5330 - accuracy: 0.8562 - val_loss: 0.4975 - val_accuracy: 0.8125
# Epoch 6/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4992 - accuracy: 0.8625 - val_loss: 0.4666 - val_accuracy: 0.8000
# Epoch 7/100
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['val_accuracy'])
